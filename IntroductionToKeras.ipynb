# %% [markdown]
# #Keras -> It is high level deep learning api build on top of tensorflow.
# It provides us ->
# 1.Model
# 2.optimisers
# 3.Loss
# 4.Metrics
# 5.Training Loops
# 6.Callbacks- Earlystopping,checkpoint,tensorboard

# %%
import tensorflow as tf 
import keras 
import numpy as np
from keras import optimizers
from keras import metrics

# %%
x_train = np.random.random((1000,20))
y_train = np.random.random((1000,1))

# %%
x_train.shape
# Out:
# (1000, 20)

# %%
y_train.shape
# Out:
# (1000, 1)

# %%
x_train[:2]
# Out:
# array([[0.86234088, 0.12421989, 0.85181806, 0.21918107, 0.98965157,
#         0.50316529, 0.77273504, 0.87256844, 0.24356059, 0.76956467,
#         0.92108931, 0.8759557 , 0.0644323 , 0.77511264, 0.81272213,
#         0.04331252, 0.06049566, 0.32195484, 0.25321014, 0.19854752],
#        [0.87341207, 0.82100098, 0.94362789, 0.52991869, 0.21909202,
#         0.29143611, 0.45681753, 0.12245836, 0.14303548, 0.22551901,
#         0.88021191, 0.59814576, 0.91176842, 0.88614969, 0.54150983,
#         0.11047929, 0.04290256, 0.14417334, 0.18275676, 0.2197382 ]])

# %%
y_train[:2]
# Out:
# array([[0.74792649],
#        [0.35404229]])

# %%
#keras Sequential api to create models
from keras.models import Sequential
from keras.layers import Dense
#Define the structure of the model
model = Sequential()
#Hidden layer 1 
model.add(Dense(128,activation='relu',input_dim=x_train.shape[1]))
#Second Hidden layer
model.add(Dense(64,activation='tanh'))
#third Layer 
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 128)            │         2,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,009 (43.00 KB)
#  Trainable params: 11,009 (43.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Configure the model for learning/training 
#loss,optimser,metrics
model.compile(loss='binary_crossentropy',optimizer='adamax',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,batch_size=10,epochs=50,verbose=1)
# Out:
# Epoch 1/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 466us/step - accuracy: 0.0000e+00 - loss: 0.6995
# Epoch 2/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - accuracy: 0.0000e+00 - loss: 0.6944
# Epoch 3/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - accuracy: 0.0000e+00 - loss: 0.6940
# Epoch 4/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - accuracy: 0.0000e+00 - loss: 0.6924
# Epoch 5/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - accuracy: 0.0000e+00 - loss: 0.6909
# Epoch 6/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.0000e+00 - loss: 0.6896
# Epoch 7/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - accuracy: 0.0000e+00 - loss: 0.6885
# Epoch 8/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - accuracy: 0.0000e+00 - loss: 0.6898
# Epoch 9/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - accuracy: 0.0000e+00 - loss: 0.6873
# Epoch 10/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - accuracy: 0.0000e+00 - loss: 0.6870
# Epoch 11/50
# ...

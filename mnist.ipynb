# %%
import tensorflow
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()

# %%
print(np.max(x_train[0]))
# Out:
# 255

# %%
print(np.min(x_train[0]))
# Out:
# 0

# %%
plt.imshow(x_train[0],cmap='gray')
plt.title(f"label {y_train[0]}")
plt.show()

# %%
x_train= x_train/255
x_test = x_test/255

# %%
from keras.models import Sequential
from keras.layers import Dense,Flatten

# %%
model = Sequential(
    [
        Flatten(input_shape=(28,28)),
        Dense(128,activation='relu'),
        Dense(64,activation='relu'),
        Dense(10,activation='sigmoid')
    ]
)
# Out:
# /Users/anuragpanchal/Documents/DeepLearning/DeepLearning/venv/lib/python3.13/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=10,validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 975us/step - accuracy: 0.9298 - loss: 0.2391 - val_accuracy: 0.9644 - val_loss: 0.1163
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 971us/step - accuracy: 0.9691 - loss: 0.1004 - val_accuracy: 0.9696 - val_loss: 0.0993
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 881us/step - accuracy: 0.9782 - loss: 0.0693 - val_accuracy: 0.9757 - val_loss: 0.0804
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 825us/step - accuracy: 0.9824 - loss: 0.0551 - val_accuracy: 0.9745 - val_loss: 0.0868
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 870us/step - accuracy: 0.9868 - loss: 0.0410 - val_accuracy: 0.9774 - val_loss: 0.0814
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 858us/step - accuracy: 0.9888 - loss: 0.0326 - val_accuracy: 0.9770 - val_loss: 0.0848
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 926us/step - accuracy: 0.9900 - loss: 0.0293 - val_accuracy: 0.9753 - val_loss: 0.0978
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 875us/step - accuracy: 0.9912 - loss: 0.0255 - val_accuracy: 0.9770 - val_loss: 0.0879
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 870us/step - accuracy: 0.9924 - loss: 0.0215 - val_accuracy: 0.9775 - val_loss: 0.0930
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 948us/step - accuracy: 0.9931 - loss: 0.0198 - val_accuracy: 0.9747 - val_loss: 0.0989

# %%
plt.plot(history.history['accuracy'],label='train_accu')
plt.plot(history.history['val_accuracy'],label='test_accua')
plt.legend()
plt.show()

# %%
loss,acc = model.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - accuracy: 0.9747 - loss: 0.0989

# %%
loss
# Out:
# 0.09894530475139618

# %%
acc
# Out:
# 0.9746999740600586

# %%
import numpy as np
pred = model.predict(x_test)
index = 9
plt.imshow(x_test[index],cmap='gray')
plt.title(f"Acutal: {y_test[index]} || predicted : {np.argmax(pred[index])}")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 290us/step
